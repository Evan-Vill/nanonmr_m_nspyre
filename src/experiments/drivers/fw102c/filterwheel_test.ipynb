# %%
from filterwheel_driver import FilterWheel

# %%
wheel = FilterWheel()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\ejvil\nspyre\src\experiments\drivers\filterwheel_driver.py:64, in USBConnection.__init__(self, portNumber)
#      63 try:
# ---> 64     self.lib=ctypes.CDLL(DLL_NAME)
#      65 except Exception as e:
#
# File c:\Users\ejvil\miniconda3\envs\nspyre\Lib\ctypes\__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#
# OSError: [WinError 193] %1 is not a valid Win32 application
#
# During handling of the above exception, another exception occurred:
#
# LibraryError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 wheel = FilterWheel()
#
# ...
